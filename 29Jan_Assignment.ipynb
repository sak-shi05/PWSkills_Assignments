# %% [markdown]
# ![image.png](attachment:14ab9626-cd03-498c-8459-4e179798a2f8.png)
#
# Ans 1) Guido van Rossum developed Python Programming Language.
#
# Ans 2) Python is an interpreted programming language, supporting object-oriented, structured, and functional programming.
#
# Ans 3) Yes, Python is case sensitive when dealing with identifier.
#
# Ans 4) .py
#
# Ans 5) Python code is interpreted.
#
# Ans 6) Indentation is used to define a block of code in python.
#
# Ans 7) #
#
# Ans 8) sys.version
#
# Ans 9) lambda
#
# Ans 10) PIP stands for Preferred Installer Program.
#
# Ans 11) print(), id(), len(), find(), type(), count(), upper(), lower(), title()
#
# Ans 12) Python identifiers are unlimited in length but as per PEP-8 you should limit identifier to a maximum of 79 character for better readability but there is no restriction.
#
# Ans 13) 1. Easy to Read, Learn and Write · 2. Improved Productivity · 3. Interpreted Language · 4. Dynamically Typed · 5. Free and Open-Source
#
# Ans 14) Memory in Python is managed by Python private heap space. All Python objects and data structures are located in a private heap. This private heap is taken care of by Python Interpreter itself, and a programmer doesn't have access to this private heap.
#
# Ans 15) Install python from this link https://www.python.org/downloads/
# After this, install it on your PC. Look for the location where PYTHON has been installed on your PC using the following command on your command prompt: cmd python.
# Then go to advanced system settings and add new variable and name it as PYTHON_NAME and paste the copied path.
# Then look for the path variable, select it's value and select edit
# Add a semicolon towards the end of the value if it's not present and then type %PYTHON_HOME%
#
# Ans 16) Yes
